# %%
# Carga de librerias
from IPython.display import display
import subprocess as sp
import numpy as np
import pandas as pd
import os
import glob
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import rcParams
from sklearn.metrics import r2_score
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams
import random
import time
from datetime import datetime
import datetime
from scipy import stats
import statsmodels.api as sm
import holidays
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler , MinMaxScaler, OrdinalEncoder
from sklearn.model_selection import train_test_split

#Modelos
from sklearn import svm
from sklearn.metrics import mean_squared_error, confusion_matrix, ConfusionMatrixDisplay
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
import pickle

# %%
dataset =  pd.read_csv('data/analytics/datasetEstudio-2021-2024MuestraEscalados.csv')
dataset.head()
# Out:
#    edad                                          NombreIPS  anio  dia  mes  \
# 0    12                  CENTRO INTEGRAL DE SALUD ARANJUEZ  2023   30    7
# 1    75    SEDE PRINCIPAL HOSPITAL ALMA MÁTER DE ANTIOQUIA  2022    9    2
# 2    46  MESSER COLOMBIA S.A. AGENCIA REMEO CENTER MEDE...  2024    7    4
# 3    92  INVERSIONES MEDICAS DE ANTIOQUIA S.A. CLINICA ...  2024   11    6
# 4    60                      IPS SURA LOS MOLINOS MEDELLIN  2022    1   11
#
#       sector_ips  atenciones_por_dia     pm25  calidad_pm25     dia_semana  \
# 0    Nororiental                   1   8.3179             1  Fin de Semana
# 1    Nororiental                 167  20.7990             1  Inicio Semana
# 2    Suroriental                  96  13.4654             1  Fin de Semana
# 3    Suroriental                  21  13.0153             1  Inicio Semana
# 4  Suroccidental                  31  17.8935             1  Inicio Semana
#
#    ... calidad_humedad  calidad_temperatura  calidad_presion  \
# 0  ...               1                  1.0                1
# 1  ...               1                  1.0                1
# 2  ...               1                  1.0                1
# 3  ...               1                  1.0                1
# 4  ...               1                  1.0                1
#
#    calidad_precipitacion  calidad_vientos  velocidad_prom  velocidad_max  \
# 0                    1.0              1.0            1.80            3.4
# 1                    1.0              1.0            0.80            1.3
# 2                    1.0              1.0            1.01            2.1
# 3                    1.0              1.0            0.62            1.2
# 4                    1.0              1.0            1.16            2.0
#
#    direccion_prom  direccion_max     comuna
# 0            98.5           83.5   comuna 4
# 1           245.0          232.0   comuna 4
# 2            78.0           80.0  comuna 14
# 3           190.0          205.0  comuna 14
# 4           241.0          246.0  comuna 16
#
# [5 rows x 26 columns]
